# %% [markdown]
# # Matplotlib example

# %%
# %run ../platzi_anaconda/plots.py

# %% [markdown]
# # Example pandas

# %%
import pandas as pd
import os

if not os.path.exists('../data/raw/sales.csv'):
  print("Creating sales.csv file...")
  # %run ../platzi_anaconda/dataset.py

data = pd.read_csv('../data/raw/sales.csv')
print(data.head())
# Out:
#          Date   Product  Quantity  Price
# 0  2025-01-10    Webcam         4  23.92
# 1  2025-01-14     Mouse         3  11.35
# 2  2025-01-18     Mouse         4  13.75
# 3  2025-02-12    Tablet         3  44.72
# 4  2025-02-16  Keyboard         5  26.95
